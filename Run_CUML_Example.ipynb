# %% [markdown]
# # Setup Instructions:
# This notebook is an example for running the GTR and/or PST using GPU-Acceleration with CUML. This notebook assumes you are running on Google Colab with GPU acceleration enabled.
#
# Take this notebook and upload it to your google drive. Open it in Colab and you should be able to clone the Granger Causality Tests for Randomness GitHub Repository and run the CUML accelerated code with the below cells.
#
# This notebook is intended to provide an example for use, that you can take and adapt to your desired use case, presumably running multiple paramerizations.

# %%
# %cd /content
# !git clone https://github.com/sillyvester/Granger-Causality-Tests-For-Randomness.git
# Out:
# /content
# Cloning into 'Granger-Causality-Tests-For-Randomness'...
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 4 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (4/4), done.

# %%
# %cd /content/Granger-Causality-Tests-For-Randomness
# Out:
# /content/Granger-Causality-Tests-For-Randomness

# %%
# %cd utils/
# %ls
# Out:
# /content/Granger-Causality-Tests-For-Randomness/utils
# cuml_utils.py  data_utils.py  granger_test_utils.py  __init__.py  __pycache__/

# %%
# For Imports
import sys
project_root = "/content/Granger-Causality-Tests-For-Randomness/"
if project_root not in sys.path:
    sys.path.append(project_root)

# For the IO
import os
os.chdir("/content/Granger-Causality-Tests-For-Randomness/")

# %%
import sys
import numpy as np
from utils import gtr_and_pst

# %%
bitstream = np.fromfile("sample_data/NIST_20000_pulses_chain2_648368_to_668367.bin", dtype=np.uint8)
bitstream = np.unpackbits(bitstream)
bitstream = bitstream[:10000000]

bitstream = bitstream.astype(np.int64)

# %%
gtr_result, pst_result, pst_recent_window_only = gtr_and_pst(bitstream, 31, 6, True, False)
print("GTR")
print(gtr_result)
print()
print("PST")
print(pst_result)
print()
print("PST recent window only")
print(pst_recent_window_only)
# Out:
# GTR
# GTR_Result(pvalue=np.float64(0.10325317770300517), llr_test_stat=41.24706005491316)
#
# PST
# PST_Result(pvalue=np.float64(0.10748116450550511), llr_test_stat=np.float64(76.09916392154992))
#
# PST recent window only
# PST_Recent_Window_Only(pvalue=np.float64(0.28969968076582264), llr_test_stat=np.float64(34.85210386663675))
